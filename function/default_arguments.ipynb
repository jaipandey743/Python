# %%
def Goodmorning(name,ending="Thank you"):
    print("Good morning," + name )
    print(ending)

Goodmorning("Jai","Thanks")
Goodmorning("Prashant",)
# Out:
# Good morning,Jai
# Thanks
# Good morning,Prashant
# Thank you
