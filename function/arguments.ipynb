# %%
def Goodmorning(name,ending):
    print("Good morning," + name )
    print(ending)

Goodmorning("Jai","Thank You")
Goodmorning("Prashant","Thank You")
Goodmorning("Rishab","Thank You")
# Out:
# Good morning,Jai
# Thank You
# Good morning,Prashant
# Thank You
# Good morning,Rishab
# Thank You
