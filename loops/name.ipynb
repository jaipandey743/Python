# %%
l=["Jai","Vedang","aayan","prashant","Jatin"]
for name in l:
    print(name)
    if name.startswith("J"):
        print ("You are welcome")
    else:
        print("go to your home")
# Out:
# Jai
# You are welcome
# Vedang
# go to your home
# aayan
# go to your home
# prashant
# go to your home
# Jatin
# You are welcome
