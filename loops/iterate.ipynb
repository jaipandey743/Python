# %%
# For loop for lists
l = [16,25,13,5,26,4] 
for i in l:
    print(i)
# Out:
# 16
# 25
# 13
# 5
# 26
# 4

# %%
# For loop for tuples
t = (423,35,240,232)
for i in t:
    print(i)
# Out:
# 423
# 35
# 240
# 232

# %%
# For loop for strings
name= "Prashant"
for i in name:
    print(i)
# Out:
# P
# r
# a
# s
# h
# a
# n
# t
