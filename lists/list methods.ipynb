# %%
friends= [1,"lucia","jason","arthur","trevor"]
print(friends)
friends.append("nico")
print(friends)
l1 = [2,55,24,25,18]
l1.sort
print(l1)
l1.insert(1,23) # insert 23 in the 2nd position
print(l1)
