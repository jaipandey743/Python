# %%
a= int(input("Enter a number:"))
b=int(input("Enter a number:"))
print("The sum of a and b is",a+b)
# If we remove int the output would be in string
# Out:
# The sum of a and b is 77
